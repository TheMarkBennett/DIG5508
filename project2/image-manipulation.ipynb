# %%
#image Maniplation

from PIL import Image, ImageDraw

filename = "project2\Mark-Bennett.png"

# %%
# Rotate an image
def roateImg(filename, degrees):

    img = Image.open(filename).rotate(degrees)

    return img

roateImg(filename, 120)

# %%
# Change an image to grayscale
def grayScale(filename):

    img = Image.open(filename).convert('LA')

    return img

grayScale(filename)

# %%
# Change the color of an image
def colorChange(filename):

    img = Image.open(filename)
    
    img = img.convert("RGBA")

    width, height = img.size

    filterImg = Image.new('RGBA', (50, 50), (0,0,0,0))

    back_im = img.copy()
    back_im.paste(filterImg, (0, 0))

    ##back_im.save('project2/filter.png', quality=95)

    return back_im

colorChange(filename)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x400 at 0x1A2FBBD3FC8>

# %%
# Change the size of an image
def imageSize(filename, i, j):

    img = Image.open(filename)

    new_img = img.resize((i,j))

    return new_img

imageSize(filename,50,50)
