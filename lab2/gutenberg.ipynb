# %% [markdown]
# # Lab 2 Part 1: Using Python to Analyze Texts
#  The first portion of this lab will involve applying concepts from the in-class exercise in order to perform common analyses. Complete any cells that are marked as ON YOUR OWN.

# %% [markdown]
#  First, you will need to install some dependencies:
#
#
#  - Install BSD-DB according to the instructions here:
#  https://github.com/c-w/Gutenberg
#
#  - Next, we'll install a library for downloading texts from gutenberg via pip. After selecting the appropriate shell for Anaconda, type the following into the terminal:
#
#  ```bash
#  pip install gutenberg
#  ```
#
#  - Finally, install TextBlob and necessary corpora:
#  ```na;j
#  pip install -U textblob
#  python -m textblob.download_corpora
#  ```

# %%
# Let's begin by downloading and using the version of Moby Dick published on Project Gutenberg.
from gutenberg.acquire import load_etext
from gutenberg.cleanup import strip_headers
from textblob import TextBlob

text = strip_headers(load_etext(2701)).strip()
blob = TextBlob(text)
# print(text)  # prints 'MOBY DICK; OR THE WHALE\n\nBy Herman Melville ...'
# This will save the text to a local .txt file in this directory.
source = open('in-class/week-6/mobydick.txt','w',encoding="utf-16",newline='\n')
source.write(text)
source.close()

# %%
type(text)
# Out:
# str

# %%
max = 0
index = 0
# Find the longest sentence in the work
for key, sentence in enumerate(blob.sentences):
    if(len(sentence.words) > max):
        max = len(sentence.words)
        index = key
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-261416ee4749> in <module>
#       3 # Find the longest sentence in the work
#       4 for key, sentence in enumerate(blob.sentences):
# ----> 5     if(len(sentence.words) > max):
#       6         max = len(sentence.words)
#       7         index = key
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\blob.py in words(self)
#     386         :returns: A :class:`WordList <WordList>` of word tokens.
#     387         """
# --> 388         return WordList(word_tokenize(self.raw, include_punc=False))
#     389
#     390     @cached_property
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\blob.py in __init__(self, collection)
#     216         its only argument.
#     217         """
# --> 218         super(WordList, self).__init__([Word(w) for w in collection])
#     219
#     220     def __str__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\blob.py in <listcomp>(.0)
#     216         its only argument.
#     217         """
# --> 218         super(WordList, self).__init__([Word(w) for w in collection])
#     219
#     220     def __str__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\tokenizers.py in <genexpr>(.0)
#      71         _word_tokenizer.itokenize(sentence, include_punc=include_punc,
#      72                                 *args, **kwargs)
# ---> 73         for sentence in sent_tokenize(text))
#      74     return words
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\base.py in itokenize(self, text, *args, **kwargs)
#      62         :rtype: generator
#      63         """
# ---> 64         return (t for t in self.tokenize(text, *args, **kwargs))
#      65
#      66 ##### SENTIMENT ANALYZERS ####
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\tokenizers.py in tokenize(self, text, include_punc)
#      32         :param include_punc: (optional) whether to include punctuation as separate tokens. Default to True.
#      33         '''
# ---> 34         tokens = nltk.tokenize.word_tokenize(text)
#      35         if include_punc:
#      36             return tokens
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     144     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     145     return [
# --> 146         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     147     ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in <listcomp>(.0)
#     144     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     145     return [
# --> 146         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     147     ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\treebank.py in tokenize(self, text, convert_parentheses, return_str)
#     117     def tokenize(self, text, convert_parentheses=False, return_str=False):
#     118         for regexp, substitution in self.STARTING_QUOTES:
# --> 119             text = regexp.sub(substitution, text)
#     120
#     121         for regexp, substitution in self.PUNCTUATION:
#
# C:\ProgramData\Anaconda3\lib\re.py in _subx(pattern, template)
#     308     # internal: Pattern.sub/subn implementation helper
#     309     template = _compile_repl(template, pattern)
# --> 310     if not template[0] and len(template[1]) == 1:
#     311         # literal replacement
#     312         return template[1][0]
#
# KeyboardInterrupt:

# %%
# Find the longest word in the work
max = 0
for key, word in enumerate(blob.words):
    if(len(word) > max):
        max = len(word)
        index = key
print(max)
print(blob.words[index])

# %% [markdown]
# # Parts of Speech
#
# Another method Montfort described is to use the tags to count certain parts of speech. Below is an example that uses a single sentence, but the same could be applied to a full manuscript.

# %%
pride = TextBlob('''It is a truth universally acknowledged, 
that a single man in possession of a good fortune, must be in 
want of a wife.''')

# %%
def adjs(pride):
    count = 0
    for (word, tag) in pride.tags:
        if tag == 'JJ':
            count = count + 1
    return count

# %%
adjs(pride)
# Out:
# 2

# %% [markdown]
# # Creating Figures
# There are many ways to create figures. Below is one example of a table. You can save the figure to a file.
#
# ```
# conda install -c plotly
# ```

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Table(header=dict(values=['A Scores', 'B Scores']),
                 cells=dict(values=[[100, 90, 80, 90], [95, 85, 75, 95]]))
                     ])
fig.show()

# %% [markdown]
# # Lab 2

# %%
# [2-1] ON YOUR OWN:

# Choose a text that was not previously analyzed above from Project Gutenberg.
# 1. Write code that retrieves and writes the text to a file in the current project. You may save it to any file, but I recommend to save it to the lab2 subdirectory.

from gutenberg.acquire import load_etext
from gutenberg.cleanup import strip_headers
from textblob import TextBlob

text = strip_headers(load_etext(408)).strip()
soul = TextBlob(text)
# print(text)  # prints 'MOBY DICK; OR THE WHALE\n\nBy Herman Melville ...'
# This will save the text to a local .txt file in this directory.
source = open('lab2/thesoulsofblackfolk.txt','w',encoding="utf-16",newline='\n')
source.write(text)
source.close()

# %%
# 2. Write code that retrieves the text (if downloaded) and saves it to a variable. 
#file1 = open('lab2/thesoulsofblackfolk.txt','r')
#soul = file1.read().replace('\n', '')
##print(file1.read())

# %%
# [2-2] ON YOUR OWN:

# Write code that finds the top 5 longest sentences in the work. You may store or display them however you choose, and you may build off of the code above that finds the longest sentence.
from operator import itemgetter 

max = 0
index = 0
longest = []
# Find the longest sentence in the work
for key, sentence in enumerate(soul.sentences):
    longest.append((sentence,len(sentence.words)))
    if(len(sentence.words) > max):
        max = len(sentence.words)       
        
       
##sortedlist = sorted(longest,key-)


sortedlist = sorted(longest,key=itemgetter(1), reverse = True)


sortedlist[5:]
# Out:
# (Sentence("Here it was that the
#   Home was ruined under the very shadow of the Church, white and black;
#   here habits of shiftlessness took root, and sullen hopelessness
#   replaced hopeful strife."), 30),
#  (Sentence("We often neglect the influence
#   of the freedman before the war, because of the paucity of his numbers
#   and the small weight he had in the history of the nation."), 30),
#  (Sentence("Huddled as he was in a few centres like Philadelphia, New York, and New
#   Orleans, the masses of the freedmen sank into poverty and listlessness;
#   but not all of them."), 30),
#  (Sentence("They
#   despise the submission and subserviency of the Southern Negroes, but
#   offer no other means by which a poor and oppressed minority can exist
#   side by side with its masters."), 30),
#  (Sentence("The wretched of my race that
#   line the alleys of the nation sit fatherless and unmothered; but Love
#   sat beside his cradle, and in his ear Wisdom waited to speak."), 30),
#  (Sentence("--this, this seemed more than man could bear; and he closed the
#   door, and sank upon the steps of the chancel, and cast his robe upon
#   the floor and writhed."), 30),
#  (Sentence("He used perpetually to
#   set the quiet dining-room into waves of merriment, as he stole to his
#   place after the bell had tapped for prayers; he seemed so perfectly
#   awkward."), 30),
#  (Sentence("This last escapade was too much, and so we solemnly
#   voted "that Jones, on account of repeated disorder and inattention to
#   work, be suspended for the rest of the term.""), 30),
#  (Sentence("The man stopped short and flushed to the roots
#   of his hair, for there directly beside his reserved orchestra chairs
#   sat the Negro he had stumbled over in the hallway."), 30),
#  (Sentence("A deep longing swelled in all his
#   heart to rise with that clear music out of the dirt and dust of that
#   low life that held him prisoned and befouled."), 30),
#  (Sentence("When at last he stood upon the bluff, he turned to his little sister
#   and looked upon her sorrowfully, remembering with sudden pain how
#   little thought he had given her."), 30),
#  (Sentence("Out of them rose for me morning, noon, and night, bursts of wonderful
#   melody, full of the voices of my brothers and sisters, full of the
#   voices of the past."), 30),
#  (Sentence("Some, like "Near the
#   lake where drooped the willow," passed into current airs and their
#   source was forgotten; others were caricatured on the "minstrel" stage
#   and their memory died away."), 30),
#  (Sentence("The words that are left to us are not without interest, and, cleared of
#   evident dross, they conceal much of real poetry and meaning beneath
#   conventional theology and unmeaning rhapsody."), 30),
#  (Sentence("Strange
#   blending of love and helplessness sings through the refrain:
#
#     "Yonder's my ole mudder,
#      Been waggin' at de hill so long;
#     'Bout time she cross over,
#      Git home bime-by.""), 30),
#  (Sentence("Later days transfigured his
#   fatalism, and amid the dust and dirt the toiler sang:
#
#     "Dust, dust and ashes, fly over my grave,
#      But the Lord shall bear my spirit home.""), 30),
#  (Sentence("Just how I would do it I could never decide: by reading law, by healing
#   the sick, by telling the wonderful tales that swam in my head,--some
#   way."), 29),
#  (Sentence("The history of the American Negro is the history of this strife,--this
#   longing to attain self-conscious manhood, to merge his double self into
#   a better and truer self."), 29),
#  (Sentence("A people thus handicapped ought not to be asked to race with the world,
#   but rather allowed to give all its time and thought to its own social
#   problems."), 29),
#  (Sentence("Men call the shadow
#   prejudice, and learnedly explain it as the natural defence of culture
#   against barbarism, learning against ignorance, purity against crime,
#   the "higher" against the "lower" races."), 29),
#  (Sentence("and swears that to so much of this strange prejudice as is founded on
#   just homage to civilization, culture, righteousness, and progress, he
#   humbly bows and meekly does obeisance."), 29),
#  (Sentence(""They constitute a military resource," wrote Secretary
#   Cameron, late in 1861; "and being such, that they should not be turned
#   over to the enemy is too plain to discuss.""), 29),
#  (Sentence("All they did was needed, for the destitution of the
#   freedmen was often reported as "too appalling for belief," and the
#   situation was daily growing worse rather than better."), 29),
#  (Sentence("And daily, too, it seemed more plain that this was no ordinary matter
#   of temporary relief, but a national crisis; for here loomed a labor
#   problem of vast dimensions."), 29),
#  (Sentence("He had marched with Sherman to the sea, had fought well at
#   Gettysburg, and but the year before had been assigned to the command of
#   the Department of Tennessee."), 29),
#  (Sentence("The Bureau invited continued cooperation with benevolent
#   societies, and declared: "It will be the object of all commissioners to
#   introduce practicable systems of compensated labor," and to establish
#   schools."), 29),
#  (Sentence("Lee had
#   surrendered, Lincoln was dead, and Johnson and Congress were at
#   loggerheads; the Thirteenth Amendment was adopted, the Fourteenth
#   pending, and the Fifteenth declared in force in 1870."), 29),
#  (Sentence("The passing of a great human institution before its work is done, like
#   the untimely passing of a single soul, but leaves a legacy of striving
#   for other men."), 29),
#  (Sentence("Honest and
#   earnest criticism from those whose interests are most nearly
#   touched,--criticism of writers by readers,--this is the soul of
#   democracy and the safeguard of modern society."), 29),
#  (Sentence("Yet there is also irreparable loss,--a loss of that peculiarly valuable
#   education which a group receives when by search and criticism it finds
#   and commissions its own leaders."), 29),
#  (Sentence("The black men of America have a duty to perform, a duty stern and
#   delicate,--a forward movement to oppose a part of the work of their
#   greatest leader."), 29),
#  (Sentence("Once upon a time I taught school in the hills of Tennessee, where the
#   broad dark vale of the Mississippi begins to roll and crumple to greet
#   the Alleghanies."), 29),
#  (Sentence("I saw much of this family afterwards, and grew to love
#   them for their honest efforts to be decent and comfortable, and for
#   their knowledge of their own ignorance."), 29),
#  (Sentence("I trembled
#   when I heard the patter of little feet down the dusty road, and saw the
#   growing row of dark solemn faces and bright eager eyes facing me."), 29),
#  (Sentence("Cuddled on the hill to the north was the village
#   of the colored folks, who lived in three- or four-room unpainted
#   cottages, some neat and homelike, and some dirty."), 29),
#  (Sentence("They were never vulgar,
#   never immoral, but rather rough and primitive, with an
#   unconventionality that spent itself in loud guffaws, slaps on the back,
#   and naps in the corner."), 29),
#  (Sentence("Then we talked of death: Fanny and Fred were gone; a shadow
#   hung over the other daughter, and when it lifted she was to go to
#   Nashville to school."), 29),
#  (Sentence("So the city crowned her hundred hills with
#   factories, and stored her shops with cunning handiwork, and stretched
#   long iron ways to greet the busy Mercury in his coming."), 29),
#  (Sentence("Teach thinkers to
#   think,--a needed knowledge in a day of loose and careless logic; and
#   they whose lot is gravest must have the carefulest training to think
#   aright."), 29),
#  (Sentence("To be sure, behind this thought
#   lurks the afterthought of force and dominion,--the making of brown men
#   to delve when the temptation of beads and red calico cloys."), 29),
#  (Sentence("If the Negro was to learn, he must teach himself,
#   and the most effective help that could be given him was the
#   establishment of schools to train Negro teachers."), 29),
#  (Sentence("We
#   must not forget that most Americans answer all queries regarding the
#   Negro a priori, and that the least that human courtesy can do is to
#   listen to evidence."), 29),
#  (Sentence("The direct testimony was in almost all cases corroborated by
#   the reports of the colleges where they graduated, so that in the main
#   the reports were worthy of credence."), 29),
#  (Sentence("Is there not, with such a group and in such a
#   crisis, infinitely more danger to be apprehended from half-trained
#   minds and shallow thinking than from over-education and
#   over-refinement?"), 29),
#  (Sentence("They walk up and down the streets,
#   meet and gossip with friends, stare at the shop windows, buy coffee,
#   cheap candy, and clothes, and at dusk drive home--happy?"), 29),
#  (Sentence("Forty-five years
#   he had lived here, and now supports himself and his old wife by the
#   help of the steer tethered yonder and the charity of his black
#   neighbors."), 29),
#  (Sentence("Parks and groves were laid out, rich with
#   flower and vine, and in the midst stood the low wide-halled "big
#   house," with its porch and columns and great fireplaces."), 29),
#  (Sentence("And yet with all this there was something sordid, something forced,--a
#   certain feverish unrest and recklessness; for was not all this show and
#   tinsel built upon a groan?"), 29),
#  (Sentence("Here and there are tales of projects for money-getting,
#   born in the swift days of Reconstruction,--"improvement" companies,
#   wine companies, mills and factories; most failed, and foreigners fell
#   heir."), 29),
#  (Sentence("The poor land groans with its
#   birth-pains, and brings forth scarcely a hundred pounds of cotton to
#   the acre, where fifty years ago it yielded eight times as much."), 29),
#  (Sentence("Of his
#   meagre yield the tenant pays from a quarter to a third in rent, and
#   most of the rest in interest on food and supplies bought on credit."), 29),
#  (Sentence("Even the markets that once defied the
#   parvenu have crept one by one across the seas, and then slowly and
#   reluctantly, but surely, have started toward the Black Belt."), 29),
#  (Sentence("To-day Sam's grandson "takes up" with a
#   woman without license or ceremony; they live together decently and
#   honestly, and are, to all intents and purposes, man and wife."), 29),
#  (Sentence("Here was a man paying five dollars for goods which he could have bought
#   for three dollars cash, and raised for one dollar or one dollar and a
#   half."), 29),
#  (Sentence("And yet follow those boys:
#   they are not lazy; to-morrow morning they'll be up with the sun; they
#   work hard when they do work, and they work willingly."), 29),
#  (Sentence("Above all, they cannot see why
#   they should take unusual pains to make the white man's land better, or
#   to fatten his mule, or save his corn."), 29),
#  (Sentence("Above the croppers come the great mass of the black population who work
#   the land on their own responsibility, paying rent in cotton and
#   supported by the crop-mortgage system."), 29),
#  (Sentence("To him the Southern problem is simply that of making
#   efficient workingmen out of this material, by giving them the requisite
#   technical skill and the help of invested capital."), 29),
#  (Sentence("The centre of this spiritual turmoil has ever been the millions of
#   black freedmen and their sons, whose destiny is so fatefully bound up
#   with that of the nation."), 29),
#  (Sentence("After Emancipation, and still earlier in the North, the
#   Negro churches largely severed such affiliations as they had had with
#   the white churches, either by choice or by compulsion."), 29),
#  (Sentence("Nor is
#   this situation peculiar to the Southern United States, is it not rather
#   the only method by which undeveloped races have gained the right to
#   share modern culture?"), 29),
#  (Sentence("From the
#   low doorway the mother silently watched her boy at play, and at
#   nightfall sought him eagerly lest the shadows bear him away to the land
#   of slaves."), 29),
#  (Sentence("Yonder, behind the forests, he heard strange sounds; then glinting
#   through the trees he saw, far, far away, the bronzed hosts of a nation
#   calling,--calling faintly, calling loudly."), 29),
#  (Sentence(""Of course they are capable," he cried; "of course they can
#   learn and strive and achieve--" and "Of course," added the temptation
#   softly, "they do nothing of the sort.""), 29),
#  (Sentence("I seem to see the wide eyes of the Negro
#   wander past the Bishop's broadcloth to where the swinging glass doors
#   of the cabinet glow in the sunlight."), 29),
#  (Sentence("They who live without knew not nor
#   dreamed of that full power within, that mighty inspiration which the
#   dull gauze of caste decreed that most men should not know."), 29),
#  (Sentence("And so it drifted to
#   the next summer, and the next,--till playmates scattered, and mother
#   grew gray, and sister went up to the Judge's kitchen to work."), 29),
#  (Sentence("Thus he grew in body and soul, and with him his clothes seemed to grow
#   and arrange themselves; coat sleeves got longer, cuffs appeared, and
#   collars got less soiled."), 29),
#  (Sentence("A tinge of sarcasm crept into his speech, and a vague
#   bitterness into his life; and he sat long hours wondering and planning
#   a way around these crooked things."), 29),
#  (Sentence("If he but had some master-work, some life-service, hard,--aye, bitter
#   hard, but without the cringing and sickening servility, without the
#   cruel hurt that hardened his heart and soul."), 29),
#  (Sentence(""Perhaps," said John, as he settled himself on the train, "perhaps I am
#   to blame myself in struggling against my manifest destiny simply
#   because it looks hard and unpleasant."), 29),
#  (Sentence("The black town flocked to the depot, with a little of the white
#   at the edges,--a happy throng, with "Good-mawnings" and "Howdys" and
#   laughing and joking and jostling."), 29),
#  (Sentence("The question was, then, he added
#   reflectively, looking at the low discolored ceiling, what part the
#   Negroes of this land would take in the striving of the new century."), 29),
#  (Sentence("Then at last a low suppressed snarl came from the Amen corner,
#   and an old bent man arose, walked over the seats, and climbed straight
#   up into the pulpit."), 29),
#  (Sentence(""Oh," said he, "it's the darky that tried to force himself into a seat
#   beside the lady I was escorting--"
#
#   But Judge Henderson waited to hear no more."), 29),
#  (Sentence("He seemed a
#   young man pleasant to look upon, as he sat on the great black stump at
#   the edge of the pines idly swinging his legs and smoking."), 29),
#  (Sentence("John looked at
#   it dreamily, then walked back to the house briskly, and said in a soft
#   voice, "Mammy, I'm going away--I'm going to be free.""), 29),
#  (Sentence("Why, he was Jones, and he wondered what they would
#   all say when they knew, when they knew, in that great long dining-room
#   with its hundreds of merry eyes."), 29),
#  (Sentence("There was once a blacksmith's son born at Cadiz, New York, who in the
#   changes of time taught school in Ohio and helped defend Cincinnati from
#   Kirby Smith."), 29),
#  (Sentence("Caricature has sought again to spoil the quaint beauty of the music,
#   and has filled the air with many debased melodies which vulgar ears
#   scarce know from the real."), 29),
#  (Sentence("The songs are indeed the siftings of centuries; the music is far more
#   ancient than the words, and in it we can trace here and there signs of
#   development."), 29),
#  (Sentence("Ten master songs, more or less, one may pluck from the forest of
#   melody-songs of undoubted Negro origin and wide popular currency, and
#   songs peculiarly characteristic of the slave."), 29),
#  (Sentence("In a third chapter I have
#   pointed out the slow rise of personal leadership, and criticized
#   candidly the leader who bears the chief burden of his race to-day."), 28),
#  (Sentence("Between me and the other world there is ever an unasked question:
#   unasked by some through feelings of delicacy; by others through the
#   difficulty of rightly framing it."), 28),
#  (Sentence("They approach me in a half-hesitant sort of way, eye me curiously or
#   compassionately, and then, instead of saying directly, How does it feel
#   to be a problem?"), 28),
#  (Sentence("we are diseased and dying, cried the dark hosts; we cannot write, our
#   voting is vain; what need of education, since we must always cook and
#   serve?"), 28),
#  (Sentence("Ben Butler, in Virginia, quickly
#   declared slave property contraband of war, and put the fugitives to
#   work; while Fremont, in Missouri, declared the slaves free under
#   martial law."), 28),
#  (Sentence(""Hereafter," he commanded, "no slaves should be allowed to come into
#   your lines at all; if any come without your knowledge, when owners call
#   for them deliver them.""), 28),
#  (Sentence("It made
#   out four thousand pay-rolls a year, registered all freedmen, inquired
#   into grievances and redressed them, laid and collected taxes, and
#   established a system of public schools."), 28),
#  (Sentence("Three characteristic things one might have seen in Sherman's raid
#   through Georgia, which threw the new situation in shadowy relief: the
#   Conqueror, the Conquered, and the Negro."), 28),
#  (Sentence("The debates
#   wandered over the whole policy of the administration and the general
#   question of slavery, without touching very closely the specific merits
#   of the measure in hand."), 28),
#  (Sentence("First, thirty thousand black men were
#   transported from the refuges and relief stations back to the farms,
#   back to the critical trial of a new way of working."), 28),
#  (Sentence("In truth, the organization became
#   a vast labor bureau,--not perfect, indeed, notably defective here and
#   there, but on the whole successful beyond the dreams of thoughtful men."),
#   28),
#  (Sentence("And some felt gratitude toward the race thus sacrificed in its
#   swaddling clothes on the altar of national integrity; and some felt and
#   feel only indifference and contempt."), 28),
#  (Sentence("The influence of all of these attitudes at
#   various times can be traced in the history of the American Negro, and
#   in the evolution of his successive leaders."), 28),
#  (Sentence("Then came the Revolution of 1876, the suppression of the Negro votes,
#   the changing and shifting of ideals, and the seeking of new lights in
#   the great night."), 28),
#  (Sentence("The rich and dominating
#   North, however, was not only weary of the race problem, but was
#   investing largely in Southern enterprises, and welcomed any method of
#   peaceful cooperation."), 28),
#  (Sentence("In the
#   tiny back kitchen I was often invited to "take out and help" myself to
#   fried chicken and wheat biscuit, "meat" and corn pone, string-beans and
#   berries."), 28),
#  (Sentence("As I sat by the spring and looked on the Old and the New I
#   felt glad, very glad, and yet--
#
#   After two long drinks I started on."), 28),
#  (Sentence("The South
#   laments to-day the slow, steady disappearance of a certain type of
#   Negro,--the faithful, courteous slave of other days, with his
#   incorruptible honesty and dignified humility."), 28),
#  (Sentence("They were right when they sought to found a new
#   educational system upon the University: where, forsooth, shall we
#   ground knowledge save on the broadest and deepest knowledge?"), 28),
#  (Sentence("And to seek to make the blacksmith a scholar is
#   almost as silly as the more modern scheme of making the scholar a
#   blacksmith; almost, but not quite."), 28),
#  (Sentence("They
#   will not guide her flying feet away from the cotton and gold; for--ah,
#   thoughtful Hippomenes!--do not the apples lie in the very Way of Life?"),
#   28),
#  (Sentence("Patience, Humility, Manners, and Taste, common schools and
#   kindergartens, industrial and technical schools, literature and
#   tolerance,--all these spring from knowledge and culture, the children
#   of the university."), 28),
#  (Sentence("They must first have the common school
#   to teach them to read, write, and cipher; and they must have higher
#   schools to teach teachers for the common schools."), 28),
#  ...]

# %%
# [2-3] ON YOUR OWN:

# Using the code above for figures, create a new table that lists the top 10 most frequent words and how many times they occur in that text.

#import collections librat\y
from collections import Counter

#split the words up
split_it = soul.split()

#count those words
Counter = Counter(split_it)

# most_common() produces k frequently encountered
# input values and their respective counts.
most_occur = Counter.most_common(10)

#split the list up into two variables
first,snd = zip(*most_occur)


import plotly.graph_objects as go

fig = go.Figure(data=[go.Table(header=dict(values=['Most common words', 'Count']),
                 cells=dict(values=[first, snd]))
                     ])
fig.show()
